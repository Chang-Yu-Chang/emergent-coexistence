# %%
from community_selection.usertools import *

# %%
assumptions = make_assumptions("../data/mapping_files/input_internal.csv", 0)

# Update the assumptions
assumptions.update({
    "n_wells": 96,
    "rich_medium": False,
    "save_composition": True,
    "composition_lograte": 1,
    "save_function": False,
    "output_dir": "../data/raw/simulation/",
    "exp_id": "pair-random_pairs-1",
    "seed": 1, 
    "synthetic_community": True,
    "init_richness": 2
})


params, params_simulation , params_algorithm, plate = prepare_experiment(assumptions)
# Out:
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol

# %%
def compete_synthetics(seed = 1, init_richness = 2):
    assumptions = make_assumptions("../data/mapping_files/input_internal.csv", 0)
    
    if init_richness == 2:
        filename_prefix = "pair"
    elif init_richness == 3:
        filename_prefix = "trio"
    elif init_richness == 4:
        filename_prefix = "quartet"
    elif init_richness == 4:
        filename_prefix = "quintet"
    elif init_richness > 5:
        filename_prefix = "diverse"
        
    # Update the assumptions
    assumptions.update({
        "n_wells": 96,
        "rich_medium": False,
        "save_composition": True,
        "composition_lograte": 1,
        "save_function": False,
        "output_dir": "../data/raw/simulation/",
        "exp_id": filename_prefix + "-random_pairs-" + str(seed),
        "seed": seed,
        "synthetic_community": True,
        "init_richness": 2
    })

    params, params_simulation , params_algorithm, plate = prepare_experiment(assumptions)
    plate.N = sample_from_pool2(plate.N, assumptions, init_richness = init_richness)
    simulate_community(params = params, params_simulation = params_simulation, params_algorithm = params_algorithm,plate = plate)

# %%
for i in range(1, 21):
    compete_synthetics(seed = i, init_richness = 3)
# Out:
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-1 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-2 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-3 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-4 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-5 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-6 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-7 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-8 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-9 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-10 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-11 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-12 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-13 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-14 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-15 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-16 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-17 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-18 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-19 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# trio-random_pairs-20 finished

# %%
for i in range(1, 21):
    compete_synthetics(seed = i, init_richness = 2)
# Out:
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-1 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-2 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-3 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-4 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-5 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-6 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-7 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-8 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-9 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-10 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-11 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-12 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-13 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-14 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-15 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-16 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-17 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-18 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-19 finished
#
# Generate species paramaters
#
# Draw per-capita function and cost
#
# Constructing plate
#
# Add community function to plate
#
# Prepare Protocol
#
# Start propogation
# Transfer 1
# Transfer 2
# Transfer 3
# Transfer 4
# Transfer 5
# Transfer 6
# Transfer 7
# Transfer 8
# Transfer 9
# Transfer 10
# Transfer 11
# Transfer 12
# Transfer 13
# Transfer 14
# Transfer 15
# Transfer 16
# Transfer 17
# Transfer 18
# Transfer 19
# Transfer 20
#
# pair-random_pairs-20 finished

# %%
assumptions = make_assumptions(input_csv, row_number)
params, params_simulation , params_algorithm, plate = prepare_experiment(assumptions)
simulate_community(params = params, params_simulation = params_simulation, params_algorithm = params_algorithm,plate = plate)
save_plate(assumptions, plate)     #Save plate (will onlys save if assumptions specify that)

# %%
def sample_from_pool2(plate_N, assumptions, init_richness = 2, n=None):
    """
    Make synthetic communities with fiven initial richness    
    """
    S_tot = plate_N.shape[0] 
    N0 = np.zeros((plate_N.shape))
    consumer_index = plate_N.index
    well_names = plate_N.columns
    
    if n is None:
        n = assumptions['n_inoc']
        
    for k in range(plate_N.shape[1]):
        consumer_list = np.random.choice(S_tot, size = init_richness, replace = False) 
        
        for v in range(init_richness):
                N0[consumer_list[v], k] = n / init_richness

    N0 = pd.DataFrame(N0, index = consumer_index, columns = well_names)

    return N0
